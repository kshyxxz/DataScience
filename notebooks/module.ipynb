# %%
#os module
import os
os.getcwd()
# Out:
# 'c:\\Users\\kshy\\Documents\\DataScience\\notebooks'

# %%
os.listdir()
# Out:
# ['basics.ipynb',
#  'lib.pdf',
#  'module.ipynb',
#  'pilot.ipynb',
#  'preprocessingEDA.ipynb']

# %%
os.makedirs("Make dir test.")
