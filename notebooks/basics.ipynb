# %%
print("Hello World!")	#printing
print("Kshitiz Shrestha")	
print(19)
# Out:
# Hello World!
# Kshitiz Shrestha
# 19

# %%
type("c")
type(10)
# Out:
# int

# %%
print("Hello World".upper())
print("Hello World".lower())
print("Hello World".capitalize())
print("Hello World".title())
# Out:
# HELLO WORLD
# hello world
# Hello world
# Hello World

# %%
print("Hello World!".count('o'))
# Out:
# 2

# %%
print("Hello World!".replace('o','O'))
# Out:
# HellO WOrld!

# %%
message_1 = "I'm learning python!"
message_2 = "It is fun!"

# %%
message = message_1 + " " + message_2
message
# Out:
# "I'm learning python! It is fun!"

# %%
f'{message_1} {message_2}'
# Out:
# "I'm learning python! It is fun!"

# %%
#list

countries = ['United States',"United States",20,True,'India','China','Brazil']
countries
# Out:
# ['United States', 'United States', 20, True, 'India', 'China', 'Brazil']

# %%
print(countries[0])
print(countries[1])
print(countries[2])
print(countries[3])
print(countries[4])
print(countries[5])
print(countries[6])

print("			")

print(countries[-1])
print(countries[-2])
# Out:
# United States
# United States
# 20
# True
# India
# China
# Brazil
#
# Brazil
# China

# %%
#slicing
# list_name[start:stop]

# %%
countries[0:3]
countries[1:4]
countries[2:]
countries[:2]
# Out:
# ['United States', 'United States']

# %%
countries.append('Canada')
countries
# Out:
# ['United States',
#  'United States',
#  20,
#  True,
#  'India',
#  'China',
#  'Brazil',
#  'Canada']

# %%
countries.insert(0,'Spain')
countries
# Out:
# ['Spain',
#  'United States',
#  'United States',
#  20,
#  True,
#  'India',
#  'China',
#  'Brazil',
#  'Canada']

# %%
countries_2= ['UK','Germany','Austria']

# %%
countries + countries_2
# Out:
# ['Spain',
#  'United States',
#  'United States',
#  20,
#  True,
#  'India',
#  'China',
#  'Brazil',
#  'Canada',
#  'UK',
#  'Germany',
#  'Austria']

# %%
nested_list = [countries, countries_2]
nested_list
# Out:
# [['Spain',
#   'United States',
#   'United States',
#   20,
#   True,
#   'India',
#   'China',
#   'Brazil',
#   'Canada'],
#  ['UK', 'Germany', 'Austria']]

# %%
countries.remove('United States')
countries
# Out:
# ['Spain', 'United States', 20, True, 'India', 'China', 'Brazil', 'Canada']

# %%
countries.pop()
countries
# Out:
# ['Spain', 'United States', 20, True, 'India', 'China', 'Brazil']

# %%
del countries[2]
countries
# Out:
# ['Spain', 'United States', True, 'India', 'China', 'Brazil']

# %%
#sorting a list

numbers = [23,43,56,12,76,29,10]
numbers.sort()
numbers
# Out:
# [10, 12, 23, 29, 43, 56, 76]

# %%
numbers = [23,43,56,12,76,29,10]
numbers.sort(reverse = True)
numbers
# Out:
# [76, 56, 43, 29, 23, 12, 10]

# %%
#updating an element
numbers[0] = 33
numbers
# Out:
# [33, 56, 43, 29, 23, 12, 10]

# %%
#copying a list
new_list = countries[:]
new_list

new_list_2 = countries.copy()
new_list_2
# Out:
# ['Spain', 'United States', True, 'India', 'China', 'Brazil']

# %%
#dictionary 1:11:23
my_dict = {'key1':'value1','key2':'value2'}
my_dict
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
my_data = {
	'name':'Kshitiz',
	'age':19,
}
my_data
# Out:
# {'name': 'Kshitiz', 'age': 19}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values()
# Out:
# dict_values(['Kshitiz', 19])

# %%
my_data.items()
# Out:
# dict_items([('name', 'Kshitiz'), ('age', 19)])

# %%
my_data['height'] = 1.8
my_data
# Out:
# {'name': 'Kshitiz', 'age': 19, 'height': 1.8}

# %%
my_data.update({'height':1.9})
my_data
# Out:
# {'name': 'Kshitiz', 'age': 19, 'height': 1.9}

# %%
new_dict = my_data.copy()
new_dict
# Out:
# {'name': 'Kshitiz', 'age': 19, 'height': 1.9}

# %%
my_data.pop('name')
my_data
# Out:
# {'age': 19, 'height': 1.9}

# %%
del my_data['age']
my_data
# Out:
# {'height': 1.9}

# %%
my_data.clear()
my_data
# Out:
# {}

# %%
#if statement
age = 18

if age>=18:
	print(f'{age} is an adult.')
elif age>=50:
	print(f'{age} is elderly.')
else:
	print(f'{age} is a child')
# Out:
# 18 is an adult.

# %%
#for loop
countries = ['United States','India','China','Brazil']
for country in countries:
	print(country)
# Out:
# United States
# India
# China
# Brazil

# %%
for i, country in enumerate(countries):
	print(f'{i} {country}')
# Out:
# 0 United States
# 1 India
# 2 China
# 3 Brazil

# %%
my_data = {
	'name':'Kshitiz',
	'age':19
}

for key, value in my_data.items():
	print(f'{key} {value}')
# Out:
# name Kshitiz
# age 19

# %%
#function
def sum_values(a,b):
	return a+b
print(sum_values(2,3))
# Out:
# 5

# %%
#built-in functions
countries
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
len(countries)
# Out:
# 4

# %%
numbers = [10,63,81,1,99]
print(max(numbers))
print(min(numbers))
# Out:
# 99
# 1

# %%
type(True)
# Out:
# list

# %%
for i in range(0, 10, 2):
	print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
